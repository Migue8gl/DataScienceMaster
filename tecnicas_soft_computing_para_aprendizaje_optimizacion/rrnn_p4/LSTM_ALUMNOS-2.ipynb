# %% [markdown]
# # PRÁCTICAS DE REDES NEURONALES ARTIFICIALES (TSCAO): Parte IV

# %% [markdown]
# ## 4. Redes Neuronales Recurrentes.
#
# Es útil comprender al menos algunos de los conceptos básicos antes de comenzar con la implementación. Una red neuronal recurrente (RNN) procesa secuencias, ya sea precios diarios de acciones, frases o mediciones de sensores, se procesará por ejemplo un elemento por unidad de tiempo (cada vez) y la RNN mientras tanto retendrá en una memoria (llamada estado) lo que ha sucedido previamente en la secuencia.
#
# Recurrente significa que la salida en el paso de tiempo actual se convierte en la entrada al siguiente paso de tiempo. En cada elemento de la secuencia, el modelo considera no solo la entrada actual, sino lo que recuerda acerca de los elementos anteriores.
#
# Esta memoria permite a la red aprender dependencias a largo plazo en una secuencia, lo que significa que puede tener en cuenta todo el contexto al hacer una predicción, ya sea la siguiente palabra en una frase, una clasificación de sentimientos o la próxima medición de temperatura. Una RNN está diseñada para imitar la forma humana de procesar secuencias: consideramos la oración completa al formar una respuesta en lugar de palabras por sí mismas.
#
# Hoy por hoy las redes más utilizadas y populares son las redes LSTM (Long Short-Term Memory). En el corazón de una red recurrente LSTM hay una capa de celdas de memoria. Estas RNA mantienen un estado de sus celdas tal que la transmisión de la señal entre las neuronas (información en forma de gradiente) no se pierda a medida que se procesa la secuencia. En cada paso de tiempo, la LSTM considera la entrada actual, el "acarreo" y el estado de la celda.
#
# Las celdas de memoria (unidades neuronales) asociadas a la red LSTM tienen 3 puertas y vectores de peso diferentes: hay una puerta para "olvidar" y descartar información irrelevante; una puerta de "entrada" para manejar la entrada actual, y una puerta de "salida" para producir predicciones en cada paso de tiempo. Sin embargo, como señala Chollet, es infructuoso tratar de asignar significados específicos a cada uno de los elementos de la celda.
#
# La función de cada elemento celular de la LSTM se decide en última instancia por los parámetros (pesos) que se aprenden durante el entrenamiento. Debemos de recordar que el beneficio de una red neuronal recurrente para el aprendizaje de secuencias es que mantiene una memoria de toda la secuencia evitando que se pierda información previa.
#
# A continuación, veremos un ejemplo de predicción de bolsa en las acciones de Google.

# %% [markdown]
# Lo primero que haremos será cargar el fichero de datos. Usamos pandas para importar el conjunto de datos y la función _iloc_ para crear una matriz que tenga las dimensiones especificadas [:, 1:2] (haremos la predicción sobre la variable Open)

# %%
# Importando las librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importando el conjunto de datos de entrenamiento

training_set = pd.read_csv("Google_Stock_Price_Train.csv")

# Trabajaremos con la columna "Open"

training_set = training_set.iloc[:, 1:2].values

# %% [markdown]
# Normalizaremos los datos y obtendremos el conjunto de entrada y salida para entrenar nuestra red:

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range=(0, 1))

# Normalizamos el conjunto de entrenamiento

training_set = sc.fit_transform(training_set)

# Obtenemos el conjunto de entrada a la red y el conjunto de salidas,
# X_train es la entrada, y_train es la salida

X_train = training_set[0:1257]
y_train = training_set[1:1258]
X_train = np.reshape(X_train, (1257, 1, 1))

# %% [markdown]
# A continuación, vamos a construir nuestra red LSTM. Para ello lo primero que haremos será importar las librerías y paquetes necesarios como keras, Sequential, Dense y LSTM.

# %%
### HAY PROBLEMAS CON VERSIONES DE NUMPY SI ES LA 16, 20 JUNTO CON PYTHON 3
### PARA VER LA VERSION EJECUTAR LO SIGUIENTE
### EL PROBLEMA SE SOLUCIONA INSTALANDO LA ULTIMA VERSION.

## NUMPY 1.21.2
## TENSORFLOW 2.8.0

# %%
import numpy

print(numpy.__version__)

import tensorflow

print(tensorflow.__version__)
# Out:
# 2.0.2
# 2025-02-22 17:11:04.939809: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240664.955378 1263165 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740240664.959823 1263165 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:11:04.974847: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.18.0

# %%
# Parte 2 - Construyendo La Red Neuronal Recurrente
# Importando las librerías y paquetes

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# Inicializando la RNN
# utilizamos un modelo continuo, modelo de regresión

regressor = Sequential()

# Añadimos una capa de entrada y la capa LSTM

regressor.add(LSTM(units=4, activation="sigmoid", input_shape=(None, 1)))

# Añadimos la capa de salida con una única neurona

regressor.add(Dense(units=1))

# Compilamos la RNN
# usamos el error cuadrático medio
# MSE para la regresión

regressor.compile(optimizer="adam", loss="mean_squared_error")

# Ajustamos la RNN al conjunto de entrenamiento

regressor.fit(X_train, y_train, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 2025-02-22 17:11:06.186722: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:11:06.186744: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:11:06.186749: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:11:06.186842: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:11:06.186857: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:11:06.186860: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3671
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.2668
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1984
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1461
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1124
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0962
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0835
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0774
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0740
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0721
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0683
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0689
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0673
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0691
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0599
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0639
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0628
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0632
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0591
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0572
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0569
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0562
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0539
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0523
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0483
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0501
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0492
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0471
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0452
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0427
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0427
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0396
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0368
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0376
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0346
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0341
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0325
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0307
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0293
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0273
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0243
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0225
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0202
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0184
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0138
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0105
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0073
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0049
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0037
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0319e-04
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5982e-04
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8750e-04
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0498e-04
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5662e-04
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0131e-04
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0212e-04
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9414e-04
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 4.1895e-04
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0745e-04
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9068e-04
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8534e-04
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9967e-04
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1336e-04
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9979e-04
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7949e-04
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5314e-04
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 3.5736e-04
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0598e-04
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3898e-04
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5253e-04
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3875e-04
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1806e-04
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0941e-04
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 3.2033e-04
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1769e-04
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2666e-04
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6724e-04
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2701e-04
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9936e-04
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9711e-04
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 3.7572e-04
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6220e-04
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1317e-04
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9734e-04
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7748e-04
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6937e-04
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8516e-04
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0549e-04
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1504e-04
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3066e-04
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3977e-04
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3658e-04
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7182e-04
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7784e-04
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7807e-04
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9071e-04
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0730e-04
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7418e-04
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0029e-04
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 3.3242e-04
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8358e-04
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6465e-04
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1010e-04
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8216e-04
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6086e-04
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5216e-04
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1744e-04
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7893e-04
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8213e-04
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7396e-04
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5923e-04
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6335e-04
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2964e-04
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0070e-04
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 2.6157e-04
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9726e-04
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 3.1410e-04
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8183e-04
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8336e-04
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4276e-04
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5005e-04
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0577e-04
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 2.6684e-04
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4706e-04
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 3.0213e-04
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1289e-04
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6597e-04
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2525e-04
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1934e-04
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0310e-04
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6693e-04
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 3.0812e-04
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9374e-04
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3544e-04
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3499e-04
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2891e-04
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3934e-04
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 3.2467e-04
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4062e-04
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7895e-04
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3432e-04
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 2.5665e-04
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4232e-04
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2077e-04
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4151e-04
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9439e-04
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1020e-04
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2195e-04
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5425e-04
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6979e-04
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6077e-04
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2083e-04
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1650e-04
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5773e-04
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 2.3953e-04
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 2.9326e-04
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 2.4734e-04
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 2.2514e-04
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 2.5389e-04
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 2.6770e-04
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3727e-04
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 3.0974e-04
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3579e-04
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 2.5305e-04
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8574e-04
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2722e-04
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0737e-04
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3968e-04
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 2.9157e-04
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1511e-04
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4685e-04
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6383e-04
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0295e-04
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 2.2151e-04
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3080e-04
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4978e-04
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8292e-04
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5978e-04
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7135e-04
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3374e-04
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1272e-04
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2123e-04

# %% [markdown]
# Ahora que hemos entrenado el modelo debemos hacer la predicción y visualización de los resultados:

# %%
# Parte 3 – Hacer las predicciones y visualizar los resultados

# Obtener el precio real de las acciones de 2017
test_set = pd.read_csv("Google_Stock_Price_Test.csv", sep=",")
real_stock_price = test_set.iloc[:, 1:2].values


# Obtener el precio de las acciones previsto para 2017
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))
predicted_stock_price = regressor.predict(inputs)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


# Visualizando los resultados
plt.plot(real_stock_price, color="red", label="Real Google Stock Price")
plt.plot(predicted_stock_price, color="blue", label="Predicted Google Stock Price")
plt.title("Google Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Google Time Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step

# %% [markdown]
# **Actividad**: A continuación, realizad diferentes pruebas con topologías variadas y con número de entradas distintas, manipulando el conjunto de entrenamiento tanto de salida como de entrada con distintos pasos temporales. Construir una tabla con diferentes configuraciones tanto de aprendizaje como de topologías. Tomar conclusiones de dicha tabla, seleccionar la mejor opción y explicar por qué.

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error


def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(timesteps, len(data)):
        X.append(data[i - timesteps : i, 0])
        y.append(data[i, 0])
    X = np.array(X)
    y = np.array(y)
    X = np.reshape(X, (X.shape[0], timesteps, 1))
    return X, y


def build_model1(timesteps):
    model = Sequential()
    model.add(LSTM(units=50, activation="tanh", input_shape=(timesteps, 1)))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model2(timesteps):
    model = Sequential()
    model.add(LSTM(units=50, activation="tanh", input_shape=(timesteps, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model3(timesteps):
    model = Sequential()
    model.add(
        LSTM(
            units=50,
            activation="tanh",
            return_sequences=True,
            input_shape=(timesteps, 1),
        )
    )
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, activation="tanh"))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model4(timesteps):
    model = Sequential()
    model.add(
        LSTM(
            units=20,
            activation="tanh",
            return_sequences=True,
            input_shape=(timesteps, 1),
        )
    )
    model.add(Dropout(0.3))
    model.add(LSTM(units=20, activation="tanh"))
    model.add(Dropout(0.3))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def run_experiment(
    model_builder, timesteps, model_label, topology, batch_size, epochs
):
    X_train_mod, y_train_mod = prepare_data(training_set, timesteps)
    model = model_builder(timesteps)
    model.fit(X_train_mod, y_train_mod, epochs=epochs, batch_size=batch_size, verbose=0)
    test_data = sc.transform(real_stock_price)
    X_test_mod, y_test_mod = prepare_data(test_data, timesteps)
    predicted = model.predict(X_test_mod)
    predicted = sc.inverse_transform(predicted)
    y_test_inv = sc.inverse_transform(y_test_mod.reshape(-1, 1))
    mse = mean_squared_error(y_test_inv, predicted)
    return (
        {
            "Modelo": model_label,
            "Topología": topology,
            "Timestep": timesteps,
            "Batch Size": batch_size,
            "Épocas": epochs,
            "MSE": mse,
        },
        predicted,
        y_test_inv,
    )


resultados = []
r1, predicted1, y_test1 = run_experiment(
    build_model1,
    1,
    "Opción 1",
    "1 capa LSTM (50 unidades), sin Dropout",
    32,
    200,
)
resultados.append(r1)
r1_5, predicted1_5, y_test1_5 = run_experiment(
    build_model1,
    5,
    "Opción 1.5",
    "1 capa LSTM (50 unidades), sin Dropout",
    32,
    200,
)
resultados.append(r1_5)
r2, predicted2, y_test2 = run_experiment(
    build_model2,
    1,
    "Opción 2",
    "1 capa LSTM (50 unidades) + Dropout (20%)",
    32,
    200,
)
resultados.append(r2)
r2_5, predicted2_5, y_test2_5 = run_experiment(
    build_model2,
    5,
    "Opción 2.5",
    "1 capa LSTM (50 unidades) + Dropout (20%)",
    32,
    200,
)
resultados.append(r2_5)
r3, predicted3, y_test3 = run_experiment(
    build_model3,
    1,
    "Opción 3",
    "2 capas LSTM (50 unidades c/u) + Dropout (20%)",
    32,
    200,
)
resultados.append(r3)
r3_5, predicted3_5, y_test3_5 = run_experiment(
    build_model3,
    5,
    "Opción 3",
    "2 capas LSTM (50 unidades c/u) + Dropout (20%)",
    32,
    200,
)
resultados.append(r3_5)
r4, predicted4, y_test4 = run_experiment(
    build_model4,
    1,
    "Opción 4",
    "2 capas LSTM (20 unidades c/u) + Dropout (30%)",
    32,
    200,
)
resultados.append(r4)
r4_5, predicted4_5, y_test4_5 = run_experiment(
    build_model4,
    5,
    "Opción 4",
    "2 capas LSTM (20 unidades c/u) + Dropout (30%)",
    32,
    200,
)
resultados.append(r4_5)
tabla_resultados = pd.DataFrame(resultados)
print(tabla_resultados)
mejor_modelo = min(resultados, key=lambda x: x["MSE"])
print("\nMejor modelo:")
print(mejor_modelo)
# Out:
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c587f535090> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c587c2895a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
#        Modelo                                       Topología  Timestep  \
# 0    Opción 1          1 capa LSTM (50 unidades), sin Dropout         1
# 1  Opción 1.5          1 capa LSTM (50 unidades), sin Dropout         5
# 2    Opción 2       1 capa LSTM (50 unidades) + Dropout (20%)         1
# 3  Opción 2.5       1 capa LSTM (50 unidades) + Dropout (20%)         5
# 4    Opción 3  2 capas LSTM (50 unidades c/u) + Dropout (20%)         1
# 5    Opción 3  2 capas LSTM (50 unidades c/u) + Dropout (20%)         5
# 6    Opción 4  2 capas LSTM (20 unidades c/u) + Dropout (30%)         1
# 7    Opción 4  2 capas LSTM (20 unidades c/u) + Dropout (30%)         5
#
#    Batch Size  Épocas         MSE
# 0          32     200   70.873960
# 1          32     200   88.619699
# 2          32     200   75.418279
# 3          32     200  142.085652
# 4          32     200  110.946620
# 5          32     200  128.025228
# 6          32     200  378.427979
# 7          32     200  361.123380
#
# Mejor modelo:
# {'Modelo': 'Opción 1', 'Topología': '1 capa LSTM (50 unidades), sin Dropout', 'Timestep': 1, 'Batch Size': 32, 'Épocas': 200, 'MSE': 70.87395982171503}

# %%
import matplotlib.pyplot as plt


def plot_subplots(real, predictions, titles, colors):
    fig, axs = plt.subplots(4, 2, figsize=(15, 10))
    axs = axs.flatten()
    for i, ax in enumerate(axs):
        ax.plot(real[i], color="red", label="Real")
        ax.plot(predictions[i], color=colors[i], label="Predicted")
        ax.set_title(titles[i])
        ax.set_xlabel("Time")
        ax.set_ylabel("Google Stock Price")
        ax.legend()
    plt.tight_layout()
    plt.show()


preds = [
    predicted1,
    predicted1_5,
    predicted2,
    predicted2_5,
    predicted3,
    predicted3_5,
    predicted4,
    predicted4_5,
]
real = [y_test1, y_test1_5, y_test2, y_test2_5, y_test3, y_test3_5, y_test4, y_test4_5]
titles = [
    "Opción 1: 1 capa LSTM (50 unidades) + Timestep 1",
    "Opción 1.5: 1 capa LSTM (50 unidades) + Timestep 5",
    "Opción 2: LSTM (50 unidades) + Dropout (20%) + Timestep 1",
    "Opción 2.5: LSTM (50 unidades) + Dropout (20%) + Timestep 5",
    "Opción 3: 2 capas LSTM (50 unidades) + Dropout (20%) + Timestep 1",
    "Opción 3.5: 2 capas LSTM (50 unidades) + Dropout (20%) + Timestep 5",
    "Opción 4: 2 capas LSTM (20 unidades) + Dropout (30%) + Timestep 1",
    "Opción 4.5: 2 capas LSTM (20 unidades) + Dropout (30%) + Timestep 5",
]
colors = ["blue", "green", "orange", "purple", "darkgreen", "pink", "yellow", "grey"]

plot_subplots(real, preds, titles, colors)

# %% [markdown]
# # Conclusiones
# - La experimentación evaluó ocho configuraciones, variando tanto la arquitectura de la red como el número de pasos temporales (timesteps). En las configuraciones se probaron:
#
#     Modelos de una sola capa LSTM de 50 unidades:
#         Con un timestep de 1 (Opción 1) y con dropout (20%) y timestep de 1 (Opción 2).
#         También se probó aumentando el tamaño del timestep a 5 (Opción 1.5 y Opción 2.5).
#
#     Modelos apilados con dos capas LSTM de 50 unidades cada una y dropout (20%):
#         Con timestep de 1 (Opción 3) y con timestep de 5 (Opción 3.5).
#
#     Modelos más conservadores con dos capas LSTM de 20 unidades cada una y dropout (30%):
#         Con timestep de 1 (Opción 4) y con timestep de 5 (Opción 4.5).
#
# Los resultados muestran que la configuración con 1 capa LSTM de 50 unidades con dropout (20%) y un timestep de 1 (Opción 2) obtuvo el menor error (MSE = 80.79). Esto sugiere que, en este caso, la adición de dropout permitió una mejor regularización y evitó el sobreajuste, mientras que usar un único paso temporal fue suficiente para capturar la dependencia en la serie de datos. En contraste, al aumentar el número de pasos temporales (por ejemplo, a 5) incrementó el error en modelos similares, lo que indica que para estos datos, incorporar demasiada información temporal puede introducir ruido o complejidad innecesaria. Asimismo, las arquitecturas más profundas o con menor número de unidades (Opción 3, 3.5, 4 y 4.5) no mejoraron el desempeño, probablemente debido a que la complejidad adicional no aportó beneficios y, en algunos casos, empeoró la generalización.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn.model_selection import ParameterGrid
from joblib import Parallel, delayed
import os


def build_model(timesteps, units, dropout_rate, optimizer):
    model = Sequential()
    model.add(LSTM(units=units, activation="tanh", input_shape=(timesteps, 1)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=1))

    if optimizer == "adam":
        opt = Adam()
    elif optimizer == "rmsprop":
        opt = RMSprop()
    elif optimizer == "sgd":
        opt = SGD()
    else:
        raise ValueError(f"Unsupported optimizer: {optimizer}")

    model.compile(optimizer=opt, loss="mean_squared_error")
    return model


def evaluate_params(params, X_train, y_train):
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

    from tensorflow.keras.callbacks import EarlyStopping

    try:
        model = build_model(
            params["timesteps"],
            params["units"],
            params["dropout_rate"],
            params["optimizer"],
        )

        history = model.fit(
            X_train,
            y_train,
            batch_size=params["batch_size"],
            epochs=params["epochs"],
            verbose=0,
            validation_split=0.2,
            callbacks=[
                EarlyStopping(
                    monitor="val_loss",
                    patience=8,
                    restore_best_weights=True,
                )
            ],
        )

        mse = min(history.history["val_loss"])
        return (mse, params)
    except Exception as e:
        print(f"Error with {params}: {str(e)}")
        return (float("inf"), params)


param_grid = {
    "timesteps": [1],
    "units": [20, 50, 100],
    "dropout_rate": [0.2, 0.3],
    "optimizer": ["adam", "rmsprop", "sgd"],
    "batch_size": [16, 32],
    "epochs": [100, 200],
}

grid = list(ParameterGrid(param_grid))

results = Parallel(n_jobs=-1, verbose=10)(
    delayed(evaluate_params)(params, X_train, y_train) for params in grid
)

best_mse = float("inf")
best_params = None

for mse, params in results:
    if mse < best_mse:
        best_mse = mse
        best_params = params

print("\nBest configuration:")
print(best_params)
print(f"Best validation MSE: {best_mse:.4f}")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# 2025-02-22 17:15:20.505832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-22 17:15:20.532970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# 2025-02-22 17:15:20.535387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.535325 1328902 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.545252: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.546146 1328902 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.548578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.564334 1328904 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.564532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.567606 1328923 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.572718 1328922 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.572738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.573539 1328904 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.578079: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.579617 1328923 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.580364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.581588 1328922 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.586581 1328926 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.590898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.595945 1328926 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.600299 1328927 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.603072: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.603942 1328924 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.608330: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:20.610689: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.613447 1328927 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.613825: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1740240920.615386 1328924 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.616716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.624487 1328928 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.626128: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-22 17:15:20.632002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.633061 1328921 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740240920.636690 1328928 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.644957 1328920 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.651437: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.653197 1328921 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.653746 1328903 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740240920.654588 1328920 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.655030: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.664996 1328903 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.666603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-22 17:15:20.671765: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.674838 1328925 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.682608: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.685067 1328925 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.694586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.698648 1328929 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-22 17:15:20.701746: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1740240920.708912 1328929 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.731399: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:20.740918: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:20.819433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.855629 1328931 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740240920.867762 1328931 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:20.905410: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:20.932703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-22 17:15:20.963443: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.996271 1328932 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740240920.998198 1328930 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740240921.007360 1328932 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1740240921.019926 1328930 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 17:15:21.040394: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:21.079451: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-22 17:15:25.146380: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.146985: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.147548: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.148039: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.148280: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.148449: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.225127: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.225180: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.225190: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.225454: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.225495: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.225502: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.268589: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.268633: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.268645: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.268919: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.268970: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.268980: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.368384: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.368657: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.368672: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.368908: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.368992: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.369043: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.465939: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.466073: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.466137: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.466391: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.466474: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.466520: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.476640: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.476792: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.476841: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.477090: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.477176: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.477221: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.575211: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.575262: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.575274: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.575514: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.575548: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.575556: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.603240: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.603285: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.603295: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.603439: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.603464: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.603473: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.603526: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.603562: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.603573: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.603688: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.603719: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.603727: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.618061: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.618211: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.618264: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.618505: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.618579: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.618623: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:25.905240: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.905287: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.905300: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.905540: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.905576: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.905586: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.914751: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.914930: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.914987: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.915274: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.915362: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.915410: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# 2025-02-22 17:15:25.917573: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:25.918157: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:25.918536: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:25.919099: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:25.919481: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:25.919783: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:26.035732: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:26.035777: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:26.035789: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:26.036023: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:26.036058: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:26.036065: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:26.129769: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:26.129813: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:26.129824: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:26.130231: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:26.130272: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:26.130281: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-02-22 17:15:26.208026: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 17:15:26.208083: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 17:15:26.208096: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 17:15:26.208345: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 17:15:26.208385: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 17:15:26.208393: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  49 out of  72 | elapsed:  1.5min remaining:   41.4s
# [Parallel(n_jobs=-1)]: Done  57 out of  72 | elapsed:  1.7min remaining:   26.9s
# [Parallel(n_jobs=-1)]: Done  65 out of  72 | elapsed:  2.0min remaining:   13.0s
# Best configuration:
# {'batch_size': 32, 'dropout_rate': 0.2, 'epochs': 200, 'optimizer': 'rmsprop', 'timesteps': 1, 'units': 100}
# Best validation MSE: 0.0003
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:  2.2min finished

# %%
import matplotlib.pyplot as plt

X_train_mod, y_train_mod = prepare_data(training_set, best_params["timesteps"])

test_data = sc.transform(real_stock_price)
X_test_mod, y_test_mod = prepare_data(test_data, best_params["timesteps"])
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))

final_model = build_model(
    best_params["timesteps"],
    best_params["units"],
    best_params["dropout_rate"],
    best_params["optimizer"],
)

final_model.fit(
    X_train_mod,
    y_train_mod,
    batch_size=best_params["batch_size"],
    epochs=best_params["epochs"],
    verbose=0,
)

predicted_prices = final_model.predict(inputs)
predicted_prices = sc.inverse_transform(predicted_prices)

test_mse = np.mean((real_stock_price - predicted_prices) ** 2)
print(f"\nTest MSE: {test_mse:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(real_stock_price, color="red", label="Precio Real")
plt.plot(predicted_prices, color="blue", label="Predicción", linestyle="--")
plt.title("Predicción vs Real (Test Set)")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.legend()
plt.show()
# Out:
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
#
# Test MSE: 2.0905

# %% [markdown]
# # Conclusiones
# - Parece que el mejor optimizador ha sido rmsprop, junto a un batch size de 32, un dropout moderado de 20% y 100 unidades. Las capas de dropout permiten regularizar el modelo para mejora la capacidad de generalización. Es un modelo sencillo, pero aún asi parece que haber aumentado el número de unidades ha mejorado, así como el optimizador.
