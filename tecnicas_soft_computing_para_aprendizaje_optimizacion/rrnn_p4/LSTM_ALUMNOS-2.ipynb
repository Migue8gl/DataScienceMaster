# %% [markdown]
# # PRÁCTICAS DE REDES NEURONALES ARTIFICIALES (TSCAO): Parte IV

# %% [markdown]
# ## 4. Redes Neuronales Recurrentes.
#
# Es útil comprender al menos algunos de los conceptos básicos antes de comenzar con la implementación. Una red neuronal recurrente (RNN) procesa secuencias, ya sea precios diarios de acciones, frases o mediciones de sensores, se procesará por ejemplo un elemento por unidad de tiempo (cada vez) y la RNN mientras tanto retendrá en una memoria (llamada estado) lo que ha sucedido previamente en la secuencia.
#
# Recurrente significa que la salida en el paso de tiempo actual se convierte en la entrada al siguiente paso de tiempo. En cada elemento de la secuencia, el modelo considera no solo la entrada actual, sino lo que recuerda acerca de los elementos anteriores.
#
# Esta memoria permite a la red aprender dependencias a largo plazo en una secuencia, lo que significa que puede tener en cuenta todo el contexto al hacer una predicción, ya sea la siguiente palabra en una frase, una clasificación de sentimientos o la próxima medición de temperatura. Una RNN está diseñada para imitar la forma humana de procesar secuencias: consideramos la oración completa al formar una respuesta en lugar de palabras por sí mismas.
#
# Hoy por hoy las redes más utilizadas y populares son las redes LSTM (Long Short-Term Memory). En el corazón de una red recurrente LSTM hay una capa de celdas de memoria. Estas RNA mantienen un estado de sus celdas tal que la transmisión de la señal entre las neuronas (información en forma de gradiente) no se pierda a medida que se procesa la secuencia. En cada paso de tiempo, la LSTM considera la entrada actual, el "acarreo" y el estado de la celda.
#
# Las celdas de memoria (unidades neuronales) asociadas a la red LSTM tienen 3 puertas y vectores de peso diferentes: hay una puerta para "olvidar" y descartar información irrelevante; una puerta de "entrada" para manejar la entrada actual, y una puerta de "salida" para producir predicciones en cada paso de tiempo. Sin embargo, como señala Chollet, es infructuoso tratar de asignar significados específicos a cada uno de los elementos de la celda.
#
# La función de cada elemento celular de la LSTM se decide en última instancia por los parámetros (pesos) que se aprenden durante el entrenamiento. Debemos de recordar que el beneficio de una red neuronal recurrente para el aprendizaje de secuencias es que mantiene una memoria de toda la secuencia evitando que se pierda información previa.
#
# A continuación, veremos un ejemplo de predicción de bolsa en las acciones de Google.

# %% [markdown]
# Lo primero que haremos será cargar el fichero de datos. Usamos pandas para importar el conjunto de datos y la función _iloc_ para crear una matriz que tenga las dimensiones especificadas [:, 1:2] (haremos la predicción sobre la variable Open)

# %%
# Importando las librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importando el conjunto de datos de entrenamiento

training_set = pd.read_csv("Google_Stock_Price_Train.csv")

# Trabajaremos con la columna "Open"

training_set = training_set.iloc[:, 1:2].values

# %% [markdown]
# Normalizaremos los datos y obtendremos el conjunto de entrada y salida para entrenar nuestra red:

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler(feature_range=(0, 1))

# Normalizamos el conjunto de entrenamiento

training_set = sc.fit_transform(training_set)

# Obtenemos el conjunto de entrada a la red y el conjunto de salidas,
# X_train es la entrada, y_train es la salida

X_train = training_set[0:1257]
y_train = training_set[1:1258]
X_train = np.reshape(X_train, (1257, 1, 1))

# %% [markdown]
# A continuación, vamos a construir nuestra red LSTM. Para ello lo primero que haremos será importar las librerías y paquetes necesarios como keras, Sequential, Dense y LSTM.

# %%
### HAY PROBLEMAS CON VERSIONES DE NUMPY SI ES LA 16, 20 JUNTO CON PYTHON 3
### PARA VER LA VERSION EJECUTAR LO SIGUIENTE
### EL PROBLEMA SE SOLUCIONA INSTALANDO LA ULTIMA VERSION.

## NUMPY 1.21.2
## TENSORFLOW 2.8.0

# %%
import numpy

print(numpy.__version__)

import tensorflow

print(tensorflow.__version__)
# Out:
# 2.0.2
# 2025-02-22 16:01:26.306896: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740236486.319769  304275 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740236486.323875  304275 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 16:01:26.339735: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.18.0

# %%
# Parte 2 - Construyendo La Red Neuronal Recurrente
# Importando las librerías y paquetes

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# Inicializando la RNN
# utilizamos un modelo continuo, modelo de regresión

regressor = Sequential()

# Añadimos una capa de entrada y la capa LSTM

regressor.add(LSTM(units=4, activation="sigmoid", input_shape=(None, 1)))

# Añadimos la capa de salida con una única neurona

regressor.add(Dense(units=1))

# Compilamos la RNN
# usamos el error cuadrático medio
# MSE para la regresión

regressor.compile(optimizer="adam", loss="mean_squared_error")

# Ajustamos la RNN al conjunto de entrenamiento

regressor.fit(X_train, y_train, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 2025-02-22 16:01:27.436654: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-02-22 16:01:27.436675: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: pop-os
# 2025-02-22 16:01:27.436680: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: pop-os
# 2025-02-22 16:01:27.436781: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 565.77.0
# 2025-02-22 16:01:27.436796: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 565.77.0
# 2025-02-22 16:01:27.436801: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 565.77.0
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1196
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 0.1032
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0969
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0950
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0923
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0934
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0858
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0862
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0811
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0792
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0749
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0716
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0727
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0674
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0663
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0640
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.0590
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 0.0565
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0543
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0497
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0453
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0447
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0419
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0398
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0361
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0339
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0306
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0289
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0259
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0210
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0195
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0173
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0150
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0136
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0121
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0058
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.0051
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.0043
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.0028
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4996e-04
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 8.0794e-04
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4783e-04
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 6.0216e-04
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 5.0328e-04
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 4.5248e-04
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1784e-04
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9136e-04
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 3.5174e-04
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3997e-04
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8578e-04
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5073e-04
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 2.8830e-04
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 2.9328e-04
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 3.0564e-04
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3419e-04
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 3.0581e-04
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5470e-04
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 2.8761e-04
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8069e-04
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 3.1535e-04
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 3.3271e-04
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 3.6712e-04
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4256e-04
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0285e-04
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2000e-04
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8745e-04
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 3.0986e-04
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1291e-04
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 2.7753e-04
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 3.0073e-04
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7987e-04
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9378e-04
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1310e-04
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 2.5993e-04
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 2.9804e-04
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1974e-04
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 2.7216e-04
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 2.9471e-04
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4433e-04
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 2.6178e-04
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4668e-04
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 2.7296e-04
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 3.1981e-04
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8623e-04
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9148e-04
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9577e-04
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6671e-04
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0469e-04
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5014e-04
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 2.5637e-04
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 2.9410e-04
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1392e-04
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9056e-04
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 2.5086e-04
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 2.6593e-04
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6858e-04
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 2.7983e-04
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4920e-04
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5727e-04
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 2.6432e-04
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 2.9789e-04
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 2.6244e-04
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 3.6149e-04
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4563e-04
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6826e-04
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 2.2500e-04
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 2.1837e-04
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6452e-04
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6805e-04
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 2.6888e-04
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1938e-04
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9371e-04
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 3.5300e-04
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7791e-04
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 2.9155e-04
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9253e-04
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6695e-04
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 3.0550e-04
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5606e-04
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3225e-04
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7871e-04
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4392e-04
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6812e-04
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6420e-04
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4923e-04
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5455e-04
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 3.0095e-04
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 2.4202e-04
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1586e-04
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1335e-04
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 2.4887e-04
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 2.8569e-04
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5384e-04
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3669e-04
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8459e-04
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9602e-04
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6281e-04
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 2.3963e-04
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 2.8541e-04
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1842e-04
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6366e-04
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1238e-04
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1094e-04
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 3.4726e-04
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 2.8909e-04
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2552e-04
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 2.6210e-04
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 2.5322e-04
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 2.6724e-04
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4304e-04
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9312e-04
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2969e-04
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0470e-04
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9565e-04
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 2.6963e-04
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9437e-04
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7977e-04
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9269e-04
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1604e-04
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2899e-04
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 2.5252e-04
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7010e-04
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3370e-04
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 2.3887e-04
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4208e-04
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 3.1197e-04
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 2.8323e-04
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 2.3797e-04
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 2.3538e-04
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 3.1298e-04
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5118e-04
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4869e-04
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5487e-04
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8838e-04
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7462e-04
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5146e-04
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9045e-04
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4174e-04
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3472e-04
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 2.4158e-04
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0399e-04
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4249e-04
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4826e-04
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 2.0639e-04
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4090e-04
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 2.2878e-04
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1340e-04
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9876e-04

# %% [markdown]
# Ahora que hemos entrenado el modelo debemos hacer la predicción y visualización de los resultados:

# %%
# Parte 3 – Hacer las predicciones y visualizar los resultados

# Obtener el precio real de las acciones de 2017
test_set = pd.read_csv("Google_Stock_Price_Test.csv", sep=",")
real_stock_price = test_set.iloc[:, 1:2].values


# Obtener el precio de las acciones previsto para 2017
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))
predicted_stock_price = regressor.predict(inputs)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


# Visualizando los resultados
plt.plot(real_stock_price, color="red", label="Real Google Stock Price")
plt.plot(predicted_stock_price, color="blue", label="Predicted Google Stock Price")
plt.title("Google Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Google Time Price")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %% [markdown]
# **Actividad**: A continuación, realizad diferentes pruebas con topologías variadas y con número de entradas distintas, manipulando el conjunto de entrenamiento tanto de salida como de entrada con distintos pasos temporales. Construir una tabla con diferentes configuraciones tanto de aprendizaje como de topologías. Tomar conclusiones de dicha tabla, seleccionar la mejor opción y explicar por qué.

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error


def prepare_data(data, timesteps):
    X, y = [], []
    for i in range(timesteps, len(data)):
        X.append(data[i - timesteps : i, 0])
        y.append(data[i, 0])
    X = np.array(X)
    y = np.array(y)
    X = np.reshape(X, (X.shape[0], timesteps, 1))
    return X, y


def build_model1(timesteps):
    model = Sequential()
    model.add(LSTM(units=50, activation="tanh", input_shape=(timesteps, 1)))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model2(timesteps):
    model = Sequential()
    model.add(LSTM(units=50, activation="tanh", input_shape=(timesteps, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model3(timesteps):
    model = Sequential()
    model.add(
        LSTM(
            units=50,
            activation="tanh",
            return_sequences=True,
            input_shape=(timesteps, 1),
        )
    )
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, activation="tanh"))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def build_model4(timesteps):
    model = Sequential()
    model.add(
        LSTM(
            units=20,
            activation="tanh",
            return_sequences=True,
            input_shape=(timesteps, 1),
        )
    )
    model.add(Dropout(0.3))
    model.add(LSTM(units=20, activation="tanh"))
    model.add(Dropout(0.3))
    model.add(Dense(units=1))
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model


def run_experiment(
    model_builder, timesteps, model_label, topology, batch_size, epochs, observations
):
    X_train_mod, y_train_mod = prepare_data(training_set, timesteps)
    model = model_builder(timesteps)
    model.fit(X_train_mod, y_train_mod, epochs=epochs, batch_size=batch_size, verbose=0)
    test_data = sc.transform(real_stock_price)
    X_test_mod, y_test_mod = prepare_data(test_data, timesteps)
    predicted = model.predict(X_test_mod)
    predicted = sc.inverse_transform(predicted)
    y_test_inv = sc.inverse_transform(y_test_mod.reshape(-1, 1))
    mse = mean_squared_error(y_test_inv, predicted)
    return (
        {
            "Modelo": model_label,
            "Topología": topology,
            "Timestep": timesteps,
            "Batch Size": batch_size,
            "Épocas": epochs,
            "MSE": mse,
            "Observaciones": observations,
        },
        predicted,
        y_test_inv,
    )


resultados = []
r1, predicted1, y_test1 = run_experiment(
    build_model1,
    1,
    "Opción 1",
    "1 capa LSTM (50 unidades), sin Dropout",
    32,
    200,
    "Buen desempeño en capturar tendencias generales.",
)
resultados.append(r1)
r1_5, predicted1_5, y_test1_5 = run_experiment(
    build_model1,
    5,
    "Opción 1.5",
    "1 capa LSTM (50 unidades), sin Dropout",
    32,
    200,
    "Buen desempeño en capturar tendencias generales.",
)
resultados.append(r1_5)
r2, predicted2, y_test2 = run_experiment(
    build_model2,
    1,
    "Opción 2",
    "1 capa LSTM (50 unidades) + Dropout (20%)",
    32,
    200,
    "La regularización mejora la generalización.",
)
resultados.append(r2)
r2_5, predicted2_5, y_test2_5 = run_experiment(
    build_model2,
    5,
    "Opción 2.5",
    "1 capa LSTM (50 unidades) + Dropout (20%)",
    32,
    200,
    "La regularización mejora la generalización.",
)
resultados.append(r2_5)
r3, predicted3, y_test3 = run_experiment(
    build_model3,
    1,
    "Opción 3",
    "2 capas LSTM (50 unidades c/u) + Dropout (20%)",
    32,
    200,
    "Captura dependencias temporales complejas; riesgo de sobreajuste moderado.",
)
resultados.append(r3)
r3_5, predicted3_5, y_test3_5 = run_experiment(
    build_model3,
    5,
    "Opción 3",
    "2 capas LSTM (50 unidades c/u) + Dropout (20%)",
    32,
    200,
    "Captura dependencias temporales complejas; riesgo de sobreajuste moderado.",
)
resultados.append(r3_5)
r4, predicted4, y_test4 = run_experiment(
    build_model4,
    1,
    "Opción 4",
    "2 capas LSTM (20 unidades c/u) + Dropout (30%)",
    32,
    200,
    "Modelo más conservador; reduce sobreajuste en casos de pocos datos.",
)
resultados.append(r4)
r4_5, predicted4_5, y_test4_5 = run_experiment(
    build_model4,
    5,
    "Opción 4",
    "2 capas LSTM (20 unidades c/u) + Dropout (30%)",
    32,
    200,
    "Modelo más conservador; reduce sobreajuste en casos de pocos datos.",
)
resultados.append(r4_5)
tabla_resultados = pd.DataFrame(resultados)
print(tabla_resultados)
mejor_modelo = min(resultados, key=lambda x: x["MSE"])
print("\nMejor modelo:")
print(mejor_modelo)
# Out:
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /home/migue8gl/Master/tecnicas_soft_computing_para_aprendizaje_optimizacion/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import matplotlib.pyplot as plt


def plot_subplots(real, predictions, titles, colors):
    fig, axs = plt.subplots(4, 2, figsize=(15, 10))
    axs = axs.flatten()
    for i, ax in enumerate(axs):
        ax.plot(real[i], color="red", label="Real")
        ax.plot(predictions[i], color=colors[i], label="Predicted")
        ax.set_title(titles[i])
        ax.set_xlabel("Time")
        ax.set_ylabel("Google Stock Price")
        ax.legend()
    plt.tight_layout()
    plt.show()


preds = [
    predicted1,
    predicted1_5,
    predicted2,
    predicted2_5,
    predicted3,
    predicted3_5,
    predicted4,
    predicted4_5,
]
real = [y_test1, y_test1_5, y_test2, y_test2_5, y_test3, y_test3_5, y_test4, y_test4_5]
titles = [
    "Opción 1: 1 capa LSTM (50 unidades) + Timestep 1",
    "Opción 1.5: 1 capa LSTM (50 unidades) + Timestep 5",
    "Opción 2: LSTM (50 unidades) + Dropout (20%) + Timestep 1",
    "Opción 2.5: LSTM (50 unidades) + Dropout (20%) + Timestep 5",
    "Opción 3: 2 capas LSTM (50 unidades) + Dropout (20%) + Timestep 1",
    "Opción 3.5: 2 capas LSTM (50 unidades) + Dropout (20%) + Timestep 5",
    "Opción 4: 2 capas LSTM (20 unidades) + Dropout (30%) + Timestep 1",
    "Opción 4.5: 2 capas LSTM (20 unidades) + Dropout (30%) + Timestep 5",
]
colors = ["blue", "green", "orange", "purple", "darkgreen", "pink", "yellow", "grey"]

plot_subplots(real, preds, titles, colors)
